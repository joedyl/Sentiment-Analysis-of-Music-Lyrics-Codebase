# %% [markdown]
# Checking for even sample of genres...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data1 = pd.read_csv("evenly_sampled_genius_lyrics.csv")

data1
# Out:
#                                                   title      tag  \
# 0                                                 Relax      rap
# 1                                                 Extra      rap
# 2                                          The Most Fun      rap
# 3                                            California      rap
# 4                                         Free Thinking      rap
# ...                                                 ...      ...
# 1495                                     Whiskey Chasin  country
# 1496                            Smoke In a Bar Acoustic  country
# 1497                                   Away In A Manger  country
# 1498                                  Sourwood Mountain  country
# 1499  If Youre Ever In Oklahoma - Live At INTRUST Ba...  country
#
#               artist  year  views         features  \
# 0         Rich Amiri  2022     10               {}
# 1        Lil Calorie  2020     19               {}
# ...

# %%
data1['tag'].value_counts()
# Out:
# rap        300
# rb         300
# rock       300
# pop        300
# country    300
# Name: tag, dtype: int64

# %% [markdown]
# Even sample of genres confirmed
